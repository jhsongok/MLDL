# %% [markdown]
# # Histogram

# %%
# pandas 를 불러옵니다.
import pandas as pd

# marathon_2015_2017.csv 파일을 읽어옵니다.
marathon_2015_2017 = pd.read_csv("../marathon_data/marathon_2015_2017.csv")

# matplotlib 를 불러옵니다.
import matplotlib.pyplot as plt

# seaborn 을 불러옵니다.
import seaborn as sns

# %%
# 그림틀의 크기를 지정한다.
plt.figure(figsize=(20,10))

# 단변수(하나의 변수)에 대한 데이터의 분포를 확인할 때 displot 함수를 사용합니다.
# 나이('Age')를 지정하여 histogram 분포도을 그립니다.
age_count = sns.distplot(marathon_2015_2017.Age)
age_count.set_xlabel('Ages',fontdict= {'size':16})               # x축 lable 추가
age_count.set_ylabel('Distribution Rate',fontdict= {'size':16})  # y축 lable 추가
age_count.set_title('Distribution Rate by Ages',fontsize=18)     # 차트 title 추가

# 그래프를 출력
plt.show()

# %%
# 그림틀의 크기를 지정한다.
plt.figure(figsize=(20,10))

# column chart로 나이('Age') 분포를 나타낼 수 있다.
age_count = sns.countplot('Age',data=marathon_2015_2017)   # 차트에 나타낼 데이터 선택, x축에 'Age' 지정, y축에는 counting
age_count.set_title('Distribution by Ages', fontsize=18)          # 차트 title 추가
age_count.set_xlabel('Ages', fontdict= {'size':16})               # x축 lable 추가
age_count.set_ylabel('Number of Runner', fontdict= {'size':16})   # y축 lable 추가

# 그래프를 출력
plt.show()

# %%
# 그림틀의 크기를 지정한다.
plt.figure(figsize=(20,10))

# column chart로 나이의 분포도가 높은 순으로 정렬하여 나이('Age') 분포를 나타낼 수 있다.
age_count = sns.countplot('Age',data=marathon_2015_2017,order = marathon_2015_2017['Age'].value_counts().index)

age_count.set_title('Distribution by Ages Sorted', fontsize=18)  # 차트 title 추가
age_count.set_xlabel('Ages', fontdict= {'size':16})              # x축 lable 추가
age_count.set_ylabel('Number of Runner', fontdict= {'size':16})  # y축 lable 추가

# 그래프를 출력
plt.show()
