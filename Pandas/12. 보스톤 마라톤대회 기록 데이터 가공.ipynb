# %%
import pandas as pd

# %% [markdown]
# #### 1. 원본 파일 읽어오기(DataFrame 생성)

# %%
marathon_2015 = pd.read_csv("marathon_results_2015.csv")
marathon_2016 = pd.read_csv("marathon_results_2016.csv")
marathon_2017 = pd.read_csv("marathon_results_2017.csv")

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1     NaN        NaN  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2     NaN        NaN  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3     NaN        NaN  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4     NaN        NaN  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division  Year
# ...

# %%
marathon_2015.shape
# Out:
# (26598, 25)

# %% [markdown]
# #### 2. DataFrame에 column 추가

# %%
marathon_2015['Year'] = '2015'
marathon_2016['Year'] = '2016'
marathon_2017['Year'] = '2017'

# %% [markdown]
# #### 3. DataFrame 병합하기

# %%
marathon_2015_2017 = pd.concat([marathon_2015, marathon_2016, marathon_2017], ignore_index=True, sort=False)

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53008 non-null  float64
#  1   Bib            79638 non-null  object
#  2   Name           79638 non-null  object
#  3   Age            79638 non-null  int64
#  4   M/F            79638 non-null  object
#  5   City           79637 non-null  object
#  6   State          70645 non-null  object
#  7   Country        79638 non-null  object
#  8   Citizen        3440 non-null   object
#  9   Unnamed: 9     158 non-null    object
#  10  5K             79638 non-null  object
#  11  10K            79638 non-null  object
#  12  15K            79638 non-null  object
#  13  20K            79638 non-null  object
#  14  Half           79638 non-null  object
#  15  25K            79638 non-null  object
#  16  30K            79638 non-null  object
# ...

# %% [markdown]
# #### 4. 불필요한 column 제거하기

# %%
marathon_2015_2017 = marathon_2015_2017.drop(['Unnamed: 0','Bib', 'Citizen', 'Unnamed: 9', 'Proj Time', 'Unnamed: 8'], axis=1)

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           79638 non-null  object
#  1   Age            79638 non-null  int64
#  2   M/F            79638 non-null  object
#  3   City           79637 non-null  object
#  4   State          70645 non-null  object
#  5   Country        79638 non-null  object
#  6   5K             79638 non-null  object
#  7   10K            79638 non-null  object
#  8   15K            79638 non-null  object
#  9   20K            79638 non-null  object
#  10  Half           79638 non-null  object
#  11  25K            79638 non-null  object
#  12  30K            79638 non-null  object
#  13  35K            79638 non-null  object
#  14  40K            79638 non-null  object
#  15  Pace           79638 non-null  object
#  16  Official Time  79638 non-null  object
# ...

# %%
marathon_2015_2017.head()
# Out:
#                     Name  Age M/F         City State Country       5K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  0:14:43
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  0:14:43
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  0:14:43
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  0:14:43
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  0:14:43
#
#        10K      15K      20K  ...      25K      30K      35K      40K  \
# 0  0:29:43  0:44:57  1:00:29  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1  0:29:43  0:44:58  1:00:28  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2  0:29:43  0:44:57  1:00:29  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3  0:29:44  0:45:01  1:00:29  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4  0:29:44  0:44:58  1:00:28  ...  1:16:07  1:32:00  1:47:59  2:03:27
#
#       Pace Official Time Overall  Gender  Division  Year
# 0  0:04:56       2:09:17       1       1         1  2015
# ...

# %% [markdown]
# #### 5. column 값 변환하기

# %%
# 시간 값(문자열)을 timedelta 타입으로 변환
marathon_2015_2017['5K'] = marathon_2015_2017['5K'].str.rjust(8, fillchar='0')
marathon_2015_2017['5K'] = pd.to_timedelta(marathon_2015_2017['5K'])
marathon_2015_2017['10K'] = marathon_2015_2017['10K'].str.rjust(8, fillchar='0')
marathon_2015_2017['10K'] = pd.to_timedelta(marathon_2015_2017['10K'])
marathon_2015_2017['15K'] = marathon_2015_2017['15K'].str.rjust(8, fillchar='0')
marathon_2015_2017['15K'] = pd.to_timedelta(marathon_2015_2017['15K'])
marathon_2015_2017['20K'] = marathon_2015_2017['20K'].str.rjust(8, fillchar='0')
marathon_2015_2017['20K'] = pd.to_timedelta(marathon_2015_2017['20K'])
marathon_2015_2017['Half'] = marathon_2015_2017['Half'].str.rjust(8, fillchar='0')
marathon_2015_2017['Half'] = pd.to_timedelta(marathon_2015_2017['Half'])
marathon_2015_2017['25K'] = marathon_2015_2017['25K'].str.rjust(8, fillchar='0')
marathon_2015_2017['25K'] = pd.to_timedelta(marathon_2015_2017['25K'])
marathon_2015_2017['30K'] = marathon_2015_2017['30K'].str.rjust(8, fillchar='0')
marathon_2015_2017['30K'] = pd.to_timedelta(marathon_2015_2017['30K'])
marathon_2015_2017['35K'] = marathon_2015_2017['35K'].str.rjust(8, fillchar='0')
marathon_2015_2017['35K'] = pd.to_timedelta(marathon_2015_2017['35K'])
marathon_2015_2017['40K'] = marathon_2015_2017['40K'].str.rjust(8, fillchar='0')
marathon_2015_2017['40K'] = pd.to_timedelta(marathon_2015_2017['40K'])
marathon_2015_2017['Pace'] = marathon_2015_2017['Pace'].str.rjust(8, fillchar='0')
marathon_2015_2017['Pace'] = pd.to_timedelta(marathon_2015_2017['Pace'])
marathon_2015_2017['Official Time'] = marathon_2015_2017['Official Time'].str.rjust(8, fillchar='0')
marathon_2015_2017['Official Time'] = pd.to_timedelta(marathon_2015_2017['Official Time'])

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           79638 non-null  object
#  1   Age            79638 non-null  int64
#  2   M/F            79638 non-null  object
#  3   City           79637 non-null  object
#  4   State          70645 non-null  object
#  5   Country        79638 non-null  object
#  6   5K             79638 non-null  timedelta64[ns]
#  7   10K            79638 non-null  timedelta64[ns]
#  8   15K            79638 non-null  timedelta64[ns]
#  9   20K            79638 non-null  timedelta64[ns]
#  10  Half           79638 non-null  timedelta64[ns]
#  11  25K            79638 non-null  timedelta64[ns]
#  12  30K            79638 non-null  timedelta64[ns]
#  13  35K            79638 non-null  timedelta64[ns]
#  14  40K            79638 non-null  timedelta64[ns]
# ...

# %%
marathon_2015_2017.head()
# Out:
#                     Name  Age M/F         City State Country              5K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH 0 days 00:14:43
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH 0 days 00:14:43
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN 0 days 00:14:43
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN 0 days 00:14:43
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN 0 days 00:14:43
#
#               10K             15K             20K  ...             25K  \
# 0 0 days 00:29:43 0 days 00:44:57 0 days 01:00:29  ... 0 days 01:16:07
# 1 0 days 00:29:43 0 days 00:44:58 0 days 01:00:28  ... 0 days 01:16:07
# 2 0 days 00:29:43 0 days 00:44:57 0 days 01:00:29  ... 0 days 01:16:07
# 3 0 days 00:29:44 0 days 00:45:01 0 days 01:00:29  ... 0 days 01:16:07
# 4 0 days 00:29:44 0 days 00:44:58 0 days 01:00:28  ... 0 days 01:16:07
#
#               30K             35K             40K            Pace  \
# ...

# %%
# 시간(time)을 초(seconds)로 변경
marathon_2015_2017['5K'] = marathon_2015_2017['5K'].dt.total_seconds().astype('int64')
marathon_2015_2017['10K'] = marathon_2015_2017['10K'].dt.total_seconds().astype('int64')
marathon_2015_2017['15K'] = marathon_2015_2017['15K'].dt.total_seconds().astype('int64')
marathon_2015_2017['20K'] = marathon_2015_2017['20K'].dt.total_seconds().astype('int64')
marathon_2015_2017['Half'] = marathon_2015_2017['Half'].dt.total_seconds().astype('int64')
marathon_2015_2017['25K'] = marathon_2015_2017['25K'].dt.total_seconds().astype('int64')
marathon_2015_2017['30K'] = marathon_2015_2017['30K'].dt.total_seconds().astype('int64')
marathon_2015_2017['35K'] = marathon_2015_2017['35K'].dt.total_seconds().astype('int64')
marathon_2015_2017['40K'] = marathon_2015_2017['40K'].dt.total_seconds().astype('int64')
marathon_2015_2017['Pace'] = marathon_2015_2017['Pace'].dt.total_seconds().astype('int64')
marathon_2015_2017['Official Time'] = marathon_2015_2017['Official Time'].dt.total_seconds().astype('int64')

# %%
marathon_2015_2017
# Out:
#                            Name  Age M/F          City State Country    5K  \
# 0                Desisa, Lelisa   25   M          Ambo   NaN     ETH   883
# 1         Tsegay, Yemane Adhane   30   M   Addis Ababa   NaN     ETH   883
# 2                Chebet, Wilson   29   M      Marakwet   NaN     KEN   883
# 3              Kipyego, Bernard   28   M       Eldoret   NaN     KEN   883
# 4                 Korir, Wesley   32   M        Kitale   NaN     KEN   883
# ...                         ...  ...  ..           ...   ...     ...   ...
# 79633  Steinbach, Paula Eyvonne   61   F       Ontario    CA     USA  2804
# 79634        Avelino, Andrew R.   25   M  Fayetteville    NC     USA  1923
# 79635           Hantel, Johanna   57   F       Malvern    PA     USA  3191
# 79636              Reilly, Bill   64   M      New York    NY     USA  2434
# 79637             Rigsby, Scott   48   M    Alpharetta    GA     USA  2376
#
#         10K   15K    20K  ...    25K    30K    35K    40K  Pace  \
# ...

# %% [markdown]
# #### 6. 가공된 DataFrame을 csv파일로 저장하기

# %%
marathon_2015_2017.to_csv("marathon_2015_2017.csv", index = None, header=True)
